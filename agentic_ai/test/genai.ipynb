# %%
from dotenv import load_dotenv
from google.genai import types
load_dotenv()
# Out:
# True

# %%
generation_config = types.GenerateContentConfig(
    temperature=0.7,
    thinking_config=types.ThinkingConfig(thinking_budget=1024, include_thoughts=True)
)

# %%
from llama_index.llms.google_genai import GoogleGenAI

llm = GoogleGenAI(model="gemini-2.5-pro", generation_config=generation_config)


seen_thoughts = ""
for r in llm.stream_complete("Given 5 distinct numbers, how many ways can we rearrange them?"):
    # new reasoning tokens (diff-based)
    thoughts = r.additional_kwargs.get("thoughts", "")
    if thoughts and thoughts != seen_thoughts:
        new_part = thoughts[len(seen_thoughts):]
        print("🧠 THINKING:", new_part, end="")
        seen_thoughts = thoughts
        continue

    # print answer tokens (no filtering by thoughts)
    if r.delta:
        print("💬 ANSWER:", r.delta, end="")
# Out:
# 🧠 THINKING: **Defining Permutations**
#
# I've zeroed in on the core question: figuring out all the ways to rearrange five unique numbers.  This clearly signals permutations!  Recognizing "distinct numbers" cemented that, meaning we're dealing with a pure permutation scenario where order *absolutely* matters.
#
#
# 🧠 THINKING: 🧠 THINKING: 🧠 THINKING: n scenario where order *absolutely* matters.
#
#
# **Confirming the Factorial**
#
# I've nailed the 5! calculation: it's 120. Now, I'm shaping the explanation, leading with the answer then defining "permutation" and showcasing the factorial logic. This lays out the step-by-step reasoning clearly, starting with 5 options, then 4, and so on.
#
#
# **Structuring the Explanation**
#
# I've crafted the explanation, starting with the answer (120 ways) then defining permutations and presenting the step-by-step logic. The explanation uses the factorial concept. The structure should be easy to follow.
#
#
# 💬 ANSWER:  finding the number of possible permutations. For 5 distinct numbers, you can think about it like this:
#
# *   For💬 ANSWER:  the **first position**, you have **5** choices.
# *   Once you've chosen the first number, you💬 ANSWER:  have **4** numbers left for the **second position**.
# *   Then, you have **3** choices for the **third💬 ANSWER:  position**.
# *   Then, **2** choices for the **fourth position**.
# *   Finally, only **1** number💬 ANSWER:  is left for the **last position**.
#
# To find the total number of ways, you multiply the choices together:
#
# 5💬 ANSWER:  × 4 × 3 × 2 × 1 = **120**
#
# This calculation is also known as a💬 ANSWER:  **factorial**, written as **5!**.
#
# So, there are **120** ways to rearrange 5💬 ANSWER:  distinct numbers.
