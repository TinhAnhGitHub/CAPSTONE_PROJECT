# %%
from abc import abstractmethod, ABC
from pymilvus import AsyncMilvusClient
from typing import Iterable, TypeVar, Generic
from pydantic import BaseModel
from loguru import logger

# %%
client = AsyncMilvusClient(uri="")
