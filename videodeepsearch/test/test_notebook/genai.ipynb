# %%
from dotenv import load_dotenv
from google.genai import types
load_dotenv()
# Out:
# True

# %%
generation_config = types.GenerateContentConfig(
    temperature=0.7,
    thinking_config=types.ThinkingConfig(thinking_budget=1024, include_thoughts=True)
)

# %%
from llama_index.llms.google_genai import GoogleGenAI
from llama_index.core.base.llms.types import ThinkingBlock, ContentBlock, TextBlock
from llama_index.core.llms import ChatMessage, ChatResponse, MessageRole

llm = GoogleGenAI(model="gemini-2.5-pro", generation_config=generation_config)

prompt = ChatMessage(
   role=MessageRole.USER,
   content="Given 5 distinct numbers, how many ways can we rearrange them?" 
)


thought = ""
last_len= 0
async for r in await llm.astream_chat([prompt]):
    message_blocks: list[ContentBlock] = r.message.blocks
    thinking_blocks = list(filter(lambda x: isinstance(x, ThinkingBlock), message_blocks))
    text_block: TextBlock = next(filter(lambda x: isinstance(x, TextBlock), message_blocks), None) #type:ignore
    
    if text_block:
        text_spawn = text_block.text
        new_text = text_spawn[last_len:]
        if new_text:
            print(new_text, end="", flush=True)
        last_len = len(text_spawn)
       
        continue

    print(thinking_blocks[-1])
# Out:
# block_type='thinking' content='**Calculating Permutations Progress**\n\nI\'ve zeroed in on the central question: determining the possible rearrangements of 5 unique numbers. The language hints strongly at a permutation problem, with the term "rearrange" and the description "distinct numbers" confirming this.\n\n\n' num_tokens=None additional_information={}
# block_type='thinking' content='**Calculating Permutations Progress**\n\nI\'ve zeroed in on the central question: determining the possible rearrangements of 5 unique numbers. The language hints strongly at a permutation problem, with the term "rearrange" and the description "distinct numbers" confirming this.\n\n\n**Deriving The Solution**\n\nI\'ve moved from recognizing the permutation problem to calculating the factorial. I\'ve now computed 5! as 120 and am focused on providing a clear explanation.\n\n\n' num_tokens=None additional_information={}
# block_type='thinking' content='**Calculating Permutations Progress**\n\nI\'ve zeroed in on the central question: determining the possible rearrangements of 5 unique numbers. The language hints strongly at a permutation problem, with the term "rearrange" and the description "distinct numbers" confirming this.\n\n\n**Deriving The Solution**\n\nI\'ve moved from recognizing the permutation problem to calculating the factorial. I\'ve now computed 5! as 120 and am focused on providing a clear explanation.\n\n\n**Crafting the Explanation**\n\nI\'m now focused on constructing the answer. I have a clear plan for the explanation: stating the answer, linking it to permutations, showing the factorial calculation, and providing an intuitive breakdown of the choices. My aim is a succinct yet insightful explanation.\n\n\n' num_tokens=None additional_information={}
# This is a classic permutation problem. When you rearrange a set of distinct items, you are finding the number of possible permutations.
#
# The number of ways to rearrange 5 distinct numbers is **120**.
#
# Here's why:
#
# You can think of it as filling 5 empty slots:
#
# *   For the **first** slot, you have **5** choices.
# *   After choosing a number for the first slot, you have **4** numbers left, so you have **4** choices for the **second** slot.
# *   For the **third** slot, you have **3** choices remaining.
# *   For the **fourth** slot, you have **2** choices.
# *   For the **last** slot, you only have **1** choice left.
#
# To find the total number of arrangements, you multiply the choices together:
#
# 5 × 4 × 3 × 2 × 1 = **120**
#
# This calculation is also known as a factorial, written as **5!**.

# %%
from llama_index.core.workflow import Event

class HelloEvent(Event):
    say_hi: str 


hi = HelloEvent(say_hi="Hi")
str(hi)
# Out:
# "say_hi='Hi'"
