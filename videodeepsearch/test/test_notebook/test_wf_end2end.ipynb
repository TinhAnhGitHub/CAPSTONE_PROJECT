# %%
from bson import ObjectId

for _ in range(10):
    random_id = ObjectId()
    print(str(random_id))
# Out:
# 692ad412086ada3a309334ff
# 692ad412086ada3a30933500
# 692ad412086ada3a30933501
# 692ad412086ada3a30933502
# 692ad412086ada3a30933503
# 692ad412086ada3a30933504
# 692ad412086ada3a30933505
# 692ad412086ada3a30933506
# 692ad412086ada3a30933507
# 692ad412086ada3a30933508
