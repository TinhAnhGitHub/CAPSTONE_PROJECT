# %%
from pymilvus import (
    AsyncMilvusClient,
    DataType,
    Function,
    FunctionType,
    CollectionSchema,
)

# %%
uri = f"http://100.113.186.28:19530"
print(uri)
client = AsyncMilvusClient(
    uri=uri,
    user="",
    password="",
    db_name="default",
    timeout=5
)
# Out:
# http://100.113.186.28:19530

# %%
collections = await client.list_collections()
print(collections)

# %%
stats = await client.get_collection_stats('segment_milvus')
print(stats)
# Out:
# {'row_count': 145}
