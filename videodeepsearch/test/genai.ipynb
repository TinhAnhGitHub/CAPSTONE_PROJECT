# %%
from dotenv import load_dotenv
from google.genai import types
load_dotenv()
# Out:
# True

# %%
generation_config = types.GenerateContentConfig(
    temperature=0.7,
    thinking_config=types.ThinkingConfig(thinking_budget=1024, include_thoughts=True)
)

# %%
from llama_index.llms.google_genai import GoogleGenAI
from llama_index.core.base.llms.types import ThinkingBlock, ContentBlock, TextBlock
from llama_index.core.llms import ChatMessage, ChatResponse, MessageRole

llm = GoogleGenAI(model="gemini-2.5-pro", generation_config=generation_config)

prompt = ChatMessage(
   role=MessageRole.USER,
   content="Given 5 distinct numbers, how many ways can we rearrange them?" 
)


thought = ""
last_len= 0
async for r in await llm.astream_chat([prompt]):
    message_blocks: list[ContentBlock] = r.message.blocks
    thinking_blocks = list(filter(lambda x: isinstance(x, ThinkingBlock), message_blocks))
    text_block: TextBlock = next(filter(lambda x: isinstance(x, TextBlock), message_blocks), None) #type:ignore
    
    if text_block:
        text_spawn = text_block.text
        new_text = text_spawn[last_len:]
        if new_text:
            print(new_text, end="", flush=True)
        last_len = len(text_spawn)
       
        continue

    print(thinking_blocks[-1])
# Out:
# block_type='thinking' content='**Defining the problem.**\n\nI\'ve zeroed in on the core question: calculating the permutations of 5 distinct items, since the user\'s intent boils down to that. Recognizing the prompt\'s language, "rearrange," as a hint toward permutations clarified the underlying mathematical concept. Now, I\'m ready to determine the formula or methodology to get the answer.\n\n\n' num_tokens=None additional_information={}
# block_type='thinking' content='**Defining the problem.**\n\nI\'ve zeroed in on the core question: calculating the permutations of 5 distinct items, since the user\'s intent boils down to that. Recognizing the prompt\'s language, "rearrange," as a hint toward permutations clarified the underlying mathematical concept. Now, I\'m ready to determine the formula or methodology to get the answer.\n\n\n**Confirming the Solution**\n\nI\'ve determined that the user is seeking the number of permutations for 5 distinct items, which is 5!. Calculation gives 120, based on sequential slot filling and the factorial formula. The answer is ready to be presented, along with the reasoning.\n\n\n' num_tokens=None additional_information={}
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7663df04e450>
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[26], line 15
#      13 thought = ""
#      14 last_len= 0
# ---> 15 async for r in await llm.astream_chat([prompt]):
#      16     message_blocks: list[ContentBlock] = r.message.blocks
#      17     thinking_blocks = list(filter(lambda x: isinstance(x, ThinkingBlock), message_blocks))
#
# File ~/miniconda3/lib/python3.12/site-packages/llama_index/core/llms/callbacks.py:89, in llm_chat_callback.<locals>.wrap.<locals>.wrapped_async_llm_chat.<locals>.wrapped_gen()
#      87 last_response = None
#      88 try:
# ---> 89     async for x in f_return_val:
#      90         dispatcher.event(
#      91             LLMChatInProgressEvent(
#      92                 messages=messages,
#    (...)     95             )
#      96         )
#      97         yield cast(ChatResponse, x)
#
# File ~/miniconda3/lib/python3.12/site-packages/llama_index/llms/google_genai/base.py:438, in GoogleGenAI._astream_chat.<locals>.gen()
#     436 content = ""
#     437 thoughts = ""
# --> 438 async for r in await chat.send_message_stream(
#     439     next_msg.parts if isinstance(next_msg, types.Content) else next_msg
#     440 ):
#     441     if candidates := r.candidates:
#     442         if not candidates:
#
# File ~/miniconda3/lib/python3.12/site-packages/google/genai/chats.py:475, in AsyncChat.send_message_stream.<locals>.async_generator()
#     473 is_valid = True
#     474 chunk = None
# --> 475 async for chunk in await self._modules.generate_content_stream(  # type: ignore[attr-defined]
#     476     model=self._model,
#     477     contents=self._curated_history + [input_content],  # type: ignore[arg-type]
#     478     config=config if config else self._config,
#     479 ):
#     480   if not _validate_response(chunk):
#     481     is_valid = False
#
# File ~/miniconda3/lib/python3.12/site-packages/google/genai/models.py:6923, in AsyncModels.generate_content_stream.<locals>.async_generator(model, contents, config)
#    6915 function_map = _extra_utils.get_function_map(
#    6916     config, mcp_to_genai_tool_adapters, is_caller_method_async=True
#    6917 )
#    6919 if i == 1:
#    6920   # First request gets a function call.
#    6921   # Then get function response parts.
#    6922   # Yield chunks only if there's no function response parts.
# -> 6923   async for chunk in response:  # type: ignore[attr-defined]
#    6924     if not function_map:
#    6925       _extra_utils.append_chunk_contents(contents, chunk)
#
# File ~/miniconda3/lib/python3.12/site-packages/google/genai/models.py:5691, in AsyncModels._generate_content_stream.<locals>.async_generator()
#    5690 async def async_generator():  # type: ignore[no-untyped-def]
# -> 5691   async for response in response_stream:
#    5693     response_dict = {} if not response.body else json.loads(response.body)
#    5695     if self._api_client.vertexai:
#
# File ~/miniconda3/lib/python3.12/site-packages/google/genai/_api_client.py:1368, in BaseApiClient.async_request_streamed.<locals>.async_generator()
#    1367 async def async_generator():  # type: ignore[no-untyped-def]
# -> 1368   async for chunk in response:
#    1369     yield SdkHttpResponse(headers=response.headers, body=json.dumps(chunk))
#
# File ~/miniconda3/lib/python3.12/site-packages/google/genai/_api_client.py:256, in HttpResponse.__anext__(self)
#     254 async def __anext__(self) -> Any:
#     255   try:
# --> 256     return await self.segment_iterator.__anext__()
#     257   except StopIteration:
#     258     raise StopAsyncIteration
#
# File ~/miniconda3/lib/python3.12/site-packages/google/genai/_api_client.py:288, in HttpResponse.async_segments(self)
#     285     yield c
#     286 else:
#     287   # Iterator of objects retrieved from the API.
# --> 288   async for chunk in self._aiter_response_stream():
#     289     yield self._load_json_from_response(chunk)
#
# File ~/miniconda3/lib/python3.12/site-packages/google/genai/_api_client.py:399, in HttpResponse._aiter_response_stream(self)
#     396 try:
#     397   while True:
#     398     # Read a line from the stream. This returns bytes.
# --> 399     line_bytes = await self.response_stream.content.readline()
#     400     if not line_bytes:
#     401       break
#
# File ~/miniconda3/lib/python3.12/site-packages/aiohttp/streams.py:352, in StreamReader.readline(self)
#     351 async def readline(self) -> bytes:
# --> 352     return await self.readuntil()
#
# File ~/miniconda3/lib/python3.12/site-packages/aiohttp/streams.py:386, in StreamReader.readuntil(self, separator)
#     383         break
#     385     if not_enough:
# --> 386         await self._wait("readuntil")
#     388 return chunk
#
# File ~/miniconda3/lib/python3.12/site-packages/aiohttp/streams.py:347, in StreamReader._wait(self, func_name)
#     345 try:
#     346     with self._timer:
# --> 347         await waiter
#     348 finally:
#     349     self._waiter = None
#
# CancelledError:
